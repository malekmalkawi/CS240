# %% [markdown]
# # CS 240 Explotary Data Analysis HW#1

# %% [markdown]
# # Malek Jamal Abdulah Malkawi - 215061235

# %%
import nsfg
import thinkstats2
import thinkplot
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-8b9ada9e5b29> in <module>()
# ----> 1 import nsfg
#       2 import thinkstats2
#       3 import thinkplot
#
# ImportError: No module named nsfg

# %%
resp = nsfg.ReadFemResp()

# %%
resp.columns
# Out:
# Index([u'caseid', u'rscrinf', u'rdormres', u'rostscrn', u'rscreenhisp',
#        u'rscreenrace', u'age_a', u'age_r', u'cmbirth', u'agescrn',
#        ...
#        u'pubassis_i', u'basewgt', u'adj_mod_basewgt', u'finalwgt', u'secu_r',
#        u'sest', u'cmintvw', u'cmlstyr', u'screentime', u'intvlngth'],
#       dtype='object', length=3087)

# %%
resp.head(20)
# Out:
#     caseid  rscrinf  rdormres  rostscrn  rscreenhisp  rscreenrace  age_a  \
# 0     2298        1         5         5            1          5.0     27
# 1     5012        1         5         1            5          5.0     42
# 2    11586        1         5         1            5          5.0     43
# 3     6794        5         5         4            1          5.0     15
# 4      616        1         5         4            1          5.0     20
# 5      845        1         5         4            1          5.0     42
# 6    10333        5         5         3            1          5.0     17
# 7      855        5         5         4            5          5.0     22
# 8     8656        5         5         4            1          5.0     38
# 9     3566        5         5         4            5          5.0     21
# 10    5917        1         5         3            1          5.0     44
# 11    9200        5         5         3            1          5.0     26
# ...

# %%
resp.tail(30)
# Out:
#       caseid  rscrinf  rdormres  rostscrn  rscreenhisp  rscreenrace  age_a  \
# 7613    4640        5         5         6            5          5.0     18
# 7614    3998        5         5         2            5          5.0     24
# 7615    2432        5         5         5            5          5.0     15
# 7616    5438        1         5         3            5          5.0     30
# 7617    9643        1         5         2            5          5.0     24
# 7618    3030        1         5         1            5          5.0     34
# 7619   11585        1         5         4            5          5.0     34
# 7620    6677        1         5         4            1          5.0     26
# 7621   10744        5         5         8            5          1.0     22
# 7622    8403        5         5         4            5          5.0     19
# 7623    7574        5         5         4            5          5.0     19
# ...

# %%
print 'There are', len(resp), 'rows and', len(resp.columns),'columns'
# Out:
# There are 7643 rows and 3087 columns

# %%
resp.agescrn
# Out:
# 0       27
# 1       42
# 2       43
# 3       15
# 4       20
# 5       42
# 6       17
# 7       22
# 8       38
# 9       21
# 10      43
# 11      26
# 12      23
# 13      34
# 14      28
# 15      28
# 16      23
# 17      33
# 18      16
# 19      24
# 20      22
# 21      32
# 22      41
# 23      37
# 24      38
# 25      29
# 26      21
# 27      37
# 28      39
# 29      26
#         ..
# 7613    18
# 7614    24
# 7615    15
# 7616    30
# 7617    24
# 7618    34
# 7619    34
# 7620    26
# 7621    22
# 7622    19
# 7623    19
# 7624    37
# 7625    20
# 7626    23
# 7627    23
# 7628    17
# 7629    36
# 7630    44
# 7631    32
# 7632    40
# 7633    35
# 7634    35
# 7635    30
# 7636    41
# 7637    35
# 7638    34
# 7639    17
# 7640    29
# 7641    16
# 7642    28
# Name: agescrn, Length: 7643, dtype: int64

# %%
resp.agescrn.value_counts().sort_index()
# Out:
# 30    292
# 22    287
# 23    282
# 31    278
# 32    273
# 37    271
# 24    269
# 21    267
# 25    267
# 36    266
# 35    262
# 29    262
# 26    260
# 20    258
# 33    257
# 38    256
# 40    256
# 34    255
# 27    255
# 43    253
# 28    252
# 41    250
# 19    241
# 44    235
# 18    235
# 17    234
# 16    223
# 15    217
# 39    215
# 42    215
# Name: agescrn, dtype: int64

# %%
resp.agescrn.min()
# Out:
# 15

# %%
resp.agescrn.max()
# Out:
# 44

# %%
resp[resp.agescrn <=25].numpregs
# Out:
# 3       0.0
# 4       0.0
# 6       0.0
# 7       0.0
# 9       0.0
# 12      2.0
# 16      3.0
# 18      2.0
# 19      3.0
# 20      1.0
# 26      0.0
# 32      0.0
# 39      1.0
# 40      4.0
# 52      0.0
# 55      0.0
# 56      0.0
# 57      1.0
# 58      0.0
# 60      1.0
# 62      0.0
# 67      4.0
# 68      0.0
# 70      3.0
# 74      3.0
# 75      0.0
# 80      2.0
# 81      3.0
# 82      0.0
# 87      0.0
#        ...
# 7562    0.0
# 7567    0.0
# 7568    0.0
# 7575    1.0
# 7579    0.0
# 7580    1.0
# 7582    0.0
# 7587    0.0
# 7588    0.0
# 7589    2.0
# 7594    0.0
# 7595    0.0
# 7596    0.0
# 7597    2.0
# 7602    0.0
# 7610    0.0
# 7611    0.0
# 7613    0.0
# 7614    0.0
# 7615    0.0
# 7617    1.0
# 7621    0.0
# 7622    0.0
# 7623    0.0
# 7625    0.0
# 7626    0.0
# 7627    0.0
# 7628    0.0
# 7639    0.0
# 7641    0.0
# Name: numpregs, Length: 2780, dtype: float64

# %%
qwerty = resp[resp.agescrn <=25].numpregs

# %%
qwerty.mean()
# Out:
# 0.709143268538517

# %%
resp.fmarno
# Out:
# 0       0
# 1       2
# 2       1
# 3       0
# 4       0
# 5       1
# 6       0
# 7       0
# 8       1
# 9       0
# 10      1
# 11      1
# 12      1
# 13      2
# 14      1
# 15      0
# 16      1
# 17      1
# 18      0
# 19      1
# 20      0
# 21      1
# 22      1
# 23      1
# 24      1
# 25      0
# 26      0
# 27      1
# 28      1
# 29      1
#        ..
# 7613    0
# 7614    1
# 7615    0
# 7616    2
# 7617    1
# 7618    1
# 7619    1
# 7620    1
# 7621    0
# 7622    0
# 7623    0
# 7624    1
# 7625    0
# 7626    0
# 7627    0
# 7628    0
# 7629    1
# 7630    1
# 7631    0
# 7632    1
# 7633    1
# 7634    1
# 7635    1
# 7636    1
# 7637    1
# 7638    2
# 7639    0
# 7640    0
# 7641    0
# 7642    0
# Name: fmarno, Length: 7643, dtype: int64

# %%
hist = thinkstats2.Hist(resp.fmarno)
hist
# Out:
# Hist({0L: 3517L, 1L: 3436L, 2L: 582L, 3L: 90L, 4L: 15L, 5L: 3L})

# %%
for val,freq in hist.Items():
    print val,freq
# Out:
# 0 3517
# 1 3436
# 2 582
# 3 90
# 4 15
# 5 3

# %%
width = 0.50
thinkplot.Hist(hist,width=width)
thinkplot.Config(xlabel='# of mariage', ylabel='freq')

# %%
neverMarried = resp[resp.fmarno == 0].fmarno
neverMarried
# Out:
# 0       0
# 3       0
# 4       0
# 6       0
# 7       0
# 9       0
# 15      0
# 18      0
# 20      0
# 25      0
# 26      0
# 32      0
# 37      0
# 39      0
# 40      0
# 41      0
# 52      0
# 55      0
# 56      0
# 57      0
# 58      0
# 59      0
# 60      0
# 62      0
# 68      0
# 69      0
# 70      0
# 75      0
# 76      0
# 80      0
#        ..
# 7584    0
# 7585    0
# 7586    0
# 7587    0
# 7588    0
# 7589    0
# 7592    0
# 7594    0
# 7595    0
# 7596    0
# 7597    0
# 7600    0
# 7602    0
# 7604    0
# 7610    0
# 7611    0
# 7613    0
# 7615    0
# 7621    0
# 7622    0
# 7623    0
# 7625    0
# 7626    0
# 7627    0
# 7628    0
# 7631    0
# 7639    0
# 7640    0
# 7641    0
# 7642    0
# Name: fmarno, Length: 3517, dtype: int64

# %%
Married = resp[resp.fmarno > 0].fmarno
Married
# Out:
# 1       2
# 2       1
# 5       1
# 8       1
# 10      1
# 11      1
# 12      1
# 13      2
# 14      1
# 16      1
# 17      1
# 19      1
# 21      1
# 22      1
# 23      1
# 24      1
# 27      1
# 28      1
# 29      1
# 30      1
# 31      1
# 33      1
# 34      1
# 35      1
# 36      1
# 38      1
# 42      2
# 43      1
# 44      1
# 45      2
#        ..
# 7583    1
# 7590    1
# 7591    1
# 7593    1
# 7598    2
# 7599    3
# 7601    1
# 7603    1
# 7605    1
# 7606    1
# 7607    3
# 7608    1
# 7609    4
# 7612    1
# 7614    1
# 7616    2
# 7617    1
# 7618    1
# 7619    1
# 7620    1
# 7624    1
# 7629    1
# 7630    1
# 7632    1
# 7633    1
# 7634    1
# 7635    1
# 7636    1
# 7637    1
# 7638    2
# Name: fmarno, Length: 4126, dtype: int64

# %%
neverMarried1 = resp[resp.fmarno == 0].totincr
neverMarried1
# Out:
# 0        9
# 3       13
# 4        6
# 6        6
# 7       12
# 9       12
# 15       9
# 18       9
# 20      12
# 25       6
# 26      11
# 32      12
# 37       4
# 39       4
# 40       3
# 41       7
# 52       8
# 55      10
# 56       4
# 57       1
# 58       3
# 59       4
# 60       1
# 62      10
# 68       5
# 69       7
# 70       6
# 75       6
# 76       2
# 80       3
#         ..
# 7584    14
# 7585     9
# 7586     5
# 7587     1
# 7588     7
# 7589     1
# 7592     5
# 7594     8
# 7595     9
# 7596     7
# 7597     6
# 7600     9
# 7602     4
# 7604    14
# 7610    11
# 7611    14
# 7613    13
# 7615    14
# 7621    11
# 7622    14
# 7623    14
# 7625    14
# 7626     2
# 7627     3
# 7628    14
# 7631     1
# 7639    14
# 7640    10
# 7641    13
# 7642    11
# Name: totincr, Length: 3517, dtype: int64

# %%
Married1 = resp[resp.fmarno > 0].totincr
Married1
# Out:
# 1       10
# 2        5
# 5        7
# 8        6
# 10       9
# 11      13
# 12       7
# 13       8
# 14       6
# 16       5
# 17       2
# 19       4
# 21      12
# 22       8
# 23      13
# 24      10
# 27       2
# 28      11
# 29       9
# 30       1
# 31       8
# 33       9
# 34      12
# 35      13
# 36       7
# 38       7
# 42       6
# 43      13
# 44       8
# 45      14
#         ..
# 7583     6
# 7590    13
# 7591     9
# 7593     8
# 7598    11
# 7599    11
# 7601    12
# 7603     6
# 7605    13
# 7606     9
# 7607    14
# 7608    10
# 7609     7
# 7612    12
# 7614     7
# 7616     4
# 7617    12
# 7618     8
# 7619    14
# 7620     8
# 7624    12
# 7629     4
# 7630     5
# 7632     6
# 7633     9
# 7634     5
# 7635     8
# 7636     3
# 7637     8
# 7638    14
# Name: totincr, Length: 4126, dtype: int64

# %%
width = 0.50

s = thinkstats2.Hist(neverMarried1, label='neverMarried') 
thinkplot.Hist(s, align='right', width=width)
thinkplot.Config(xlabel='Income', ylabel='Total Income')

m = thinkstats2.Hist(Married1, label='Married') 
thinkplot.Hist(m, align='left', width=width)
thinkplot.Config(xlabel='Income', ylabel='Total Income')

# %%
singalss.min()
# Out:
# 1

# %%
singalss.max()
# Out:
# 14

# %%
singalss.std()
# Out:
# 3.9808087968344528

# %%
singalss.var()
# Out:
# 15.846838676954563

# %%
singalss.mean()
# Out:
# 8.020756326414558

# %%
marriedd.min()
# Out:
# 1

# %%
marriedd.max()
# Out:
# 14

# %%
marriedd.std()
# Out:
# 3.71465249580075

# %%
marriedd.var()
# Out:
# 13.79864316455874

# %%
marriedd.mean()
# Out:
# 9.495152690256907
